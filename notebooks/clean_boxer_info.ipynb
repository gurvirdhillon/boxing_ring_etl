# %%
import pandas as pd
import random as rd
import numpy as np

# %%
df = pd.read_csv("../data/raw/boxing_matches_messy_data.csv")
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  orthodox  orthodox
# 1   26.0   31.0     173.0     185.0    179.0    185.0  orthodox  orthodox
# 2   28.0    NaN     176.0     175.0    178.0    179.0  orthodox  orthodox
# 3   25.0   29.0     175.0     174.0    178.0    180.0  orthodox  orthodox
# 4   25.0   35.0     175.0     173.0    179.0    170.0  orthodox  orthodox
#
#    weight_A  weight_B  ...  kos_A  kos_B  result  decision  judge1_A  \
# 0     160.0     160.0  ...   33.0   34.0    draw       NaN     110.0
# 1     164.0     164.0  ...   34.0   32.0   win_A        UD     120.0
# 2     154.0     154.0  ...   13.0   33.0   win_B        KO      58.0
# 3       NaN     155.0  ...   32.0    NaN   win_A        KO      47.0
# 4     139.0     140.0  ...   32.0   33.0   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0     118.0     115.0     113.0    114.0    114.0
# 1     108.0     120.0     108.0    120.0    108.0
# 2      54.0      57.0      54.0     58.0     54.0
# 3      48.0      49.0      46.0     48.0     47.0
# 4     110.0     119.0     109.0    117.0    111.0
#
# [5 rows x 26 columns]

# %%
df.duplicated().sum()
# 15070 duplicates over the entire dataset
# Out:
# 15070

# %%
# explore the number for the columns

duplicates_columns = df.apply(lambda x: x.duplicated().sum())
print(duplicates_columns)
# Out:
# age_A       417996
# age_B       417971
# height_A    417960
# height_B    417962
# reach_A     417944
# reach_B     417928
# stance_A    418068
# stance_B    418069
# weight_A    417680
# weight_B    417648
# won_A       417636
# won_B       417735
# lost_A      417901
# lost_B      417697
# drawn_A     417967
# drawn_B     417966
# kos_A       417863
# kos_B       417906
# result      418055
# decision    418010
# judge1_A    417846
# judge1_B    417821
# judge2_A    417810
# judge2_B    417791
# judge3_A    417815
# judge3_B    417789
# dtype: int64

# %%
# a lot of duplicated data therefore we will drop the duplicates but before we do lets find out the shape
df.shape
# Out:
# (418092, 26)

# %%
duplicate_percentage = df.apply(lambda x: x.duplicated().mean() * 100).round(2)
print(duplicate_percentage)
# Out:
# age_A       99.98
# age_B       99.97
# height_A    99.97
# height_B    99.97
# reach_A     99.96
# reach_B     99.96
# stance_A    99.99
# stance_B    99.99
# weight_A    99.90
# weight_B    99.89
# won_A       99.89
# won_B       99.91
# lost_A      99.95
# lost_B      99.91
# drawn_A     99.97
# drawn_B     99.97
# kos_A       99.95
# kos_B       99.96
# result      99.99
# decision    99.98
# judge1_A    99.94
# judge1_B    99.94
# judge2_A    99.93
# judge2_B    99.93
# judge3_A    99.93
# judge3_B    99.93
# dtype: float64

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (403022, 26)

# %%
df
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B      stance_A  \
# 0        35.0   27.0     179.0     175.0    178.0    179.0      orthodox
# 1        26.0   31.0     173.0     185.0    179.0    185.0      orthodox
# 2        28.0    NaN     176.0     175.0    178.0    179.0      orthodox
# 3        25.0   29.0     175.0     174.0    178.0    180.0      orthodox
# 4        25.0   35.0     175.0     173.0    179.0    170.0      orthodox
# ...       ...    ...       ...       ...      ...      ...           ...
# 418072   24.0   27.0     184.0     185.0    178.0    196.0     orthodox
# 418076   26.0   26.0     173.0     173.0    178.0    178.0      orthodox
# 418084   26.0   34.0     171.0     170.0    169.0    178.0    orthodox
# 418085   22.0   20.0     173.0     173.0    178.0    178.0     southpaw
# 418090   33.0   19.0     173.0     173.0    178.0    178.0      southpaw
#
#         stance_B  weight_A  weight_B  ...  kos_A  kos_B     result  decision  \
# 0       orthodox     160.0     160.0  ...   33.0   34.0       draw       NaN
# 1       orthodox     164.0     164.0  ...   34.0   32.0      win_A        UD
# 2       orthodox     154.0     154.0  ...   13.0   33.0      win_B        KO
# 3       orthodox       NaN     155.0  ...   32.0    NaN      win_A        KO
# 4       orthodox     139.0     140.0  ...   32.0   33.0      win_A        UD
# ...          ...       ...       ...  ...    ...    ...        ...       ...
# 418072  orthodox     139.0     140.0  ...   12.0    3.0      win_a       PTS
# 418076  orthodox     139.0     140.0  ...   -0.0    0.0      win_A      TKO
# 418084  orthodox     139.0     140.0  ...   16.0   14.0    win_A          KO
# 418085  southpaw     139.0     140.0  ...    2.0    0.0       draw       PTS
# 418090  southpaw     139.0     140.0  ...    1.0    0.0       draw       PTS
#
#         judge1_A  judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0          110.0     118.0     115.0     113.0    114.0    114.0
# 1          120.0     108.0     120.0     108.0    120.0    108.0
# 2           58.0      54.0      57.0      54.0     58.0     54.0
# 3           47.0      48.0      49.0      46.0     48.0     47.0
# 4          118.0     110.0     119.0     109.0    117.0    111.0
# ...          ...       ...       ...       ...      ...      ...
# 418072      58.0      54.0      57.0      54.0     58.0     54.0
# 418076      58.0      54.0      57.0      54.0     58.0     54.0
# 418084      10.0       NaN      10.0       9.0     10.0      9.0
# 418085      58.0      54.0      57.0      54.0     58.0     54.0
# 418090      58.0      54.0      57.0      54.0     58.0     54.0
#
# [403022 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Duplicates removed✅

# %%
# find the number of na's within the dataset

number_of_na = df.apply(lambda x: x.isna().sum())
print(number_of_na)
# Out:
# age_A       20172
# age_B       20191
# height_A    20171
# height_B    20202
# reach_A     20203
# reach_B     20196
# stance_A    19370
# stance_B    19318
# weight_A    20215
# weight_B    20179
# won_A       20205
# won_B       20185
# lost_A      20161
# lost_B      20208
# drawn_A     20191
# drawn_B     20202
# kos_A       20194
# kos_B       20186
# result      19361
# decision    19352
# judge1_A    20198
# judge1_B    20211
# judge2_A    20215
# judge2_B    20190
# judge3_A    20169
# judge3_B    20191
# dtype: int64

# %% [markdown]
# As can be seen there are lots of missing values so we need to decide what to do with the data and a plan will be made regarding the columns on an individual basis. Further justification will be provided in the README.md file for more context.

# %%
# age will be distributed randomly amongst the boxers on a scale
# we will use a random figure between 18 to 43 to give the age for the boxers that do not have an age specified

df['age_A'] = df['age_A'].abs()
df['age_B'] = df['age_B'].abs()

df['age_A'] = df['age_A'].apply(lambda x: rd.randint(18, 43) if pd.isna(x) else x)
df['age_B'] = df['age_B'].apply(lambda x: rd.randint(18, 43) if pd.isna(x) else x)

# %%
df['age_A'].isna().sum()
# Out:
# 0

# %%
df['age_B'].isna().sum()
# Out:
# 0

# %%
df.tail()
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B      stance_A  \
# 418072   24.0   27.0     184.0     185.0    178.0    196.0     orthodox
# 418076   26.0   26.0     173.0     173.0    178.0    178.0      orthodox
# 418084   26.0   34.0     171.0     170.0    169.0    178.0    orthodox
# 418085   22.0   20.0     173.0     173.0    178.0    178.0     southpaw
# 418090   33.0   19.0     173.0     173.0    178.0    178.0      southpaw
#
#         stance_B  weight_A  weight_B  ...  kos_A  kos_B     result  decision  \
# 418072  orthodox     139.0     140.0  ...   12.0    3.0      win_a       PTS
# 418076  orthodox     139.0     140.0  ...   -0.0    0.0      win_A      TKO
# 418084  orthodox     139.0     140.0  ...   16.0   14.0    win_A          KO
# 418085  southpaw     139.0     140.0  ...    2.0    0.0       draw       PTS
# 418090  southpaw     139.0     140.0  ...    1.0    0.0       draw       PTS
#
#         judge1_A  judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 418072      58.0      54.0      57.0      54.0     58.0     54.0
# 418076      58.0      54.0      57.0      54.0     58.0     54.0
# 418084      10.0       NaN      10.0       9.0     10.0      9.0
# 418085      58.0      54.0      57.0      54.0     58.0     54.0
# 418090      58.0      54.0      57.0      54.0     58.0     54.0
#
# [5 rows x 26 columns]

# %%
outliers_age_A = df[df['age_A'] < 18]
outliers_age_B = df[df['age_B'] < 18]

outliers_age_A.count
# Out:
# <bound method DataFrame.count of         age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  \
# 31       17.0   21.0     175.0     178.0    179.0    183.0  orthodox
# 32       17.0   26.0     175.0     173.0      NaN    178.0       NaN
# 33       17.0   20.0     175.0     178.0    179.0    178.0  orthodox
# 34       17.0   26.0    -175.0     173.0    179.0    178.0       NaN
# 35       17.0   26.0     175.0     173.0    179.0    178.0  orthodox
# ...       ...    ...       ...       ...      ...      ...       ...
# 417224   17.0   33.0     161.0     165.0    165.0    178.0  orthodox
# 417445   16.0   26.0     173.0     173.0    178.0    178.0  orthodox
# 417458   17.0   26.0     173.0     173.0    183.0    178.0     nan
# 417469   17.0   26.0     161.0     173.0    178.0    178.0  southpaw
# 417775   16.0   26.0     161.0     173.0    178.0    178.0  southpaw
#
#           stance_B  weight_A  weight_B  ...  kos_A  kos_B     result  \
# 31        orthodox     139.0     140.0  ...   15.0   10.0      win_A
# 32        orthodox     147.0     140.0  ...   15.0    3.0      win_a
# 33        orthodox     147.0     140.0  ...   14.0    9.0      win_A
# 34        orthodox     147.0     147.0  ...   13.0    2.0      win_A
# 35        orthodox     148.0     140.0  ...   12.0    0.0      win_A
# ...            ...       ...       ...  ...    ...    ...        ...
# 417224    orthodox     139.0     112.0  ...    6.0   11.0     win_A
# 417445    orthodox     139.0     140.0  ...    NaN    0.0      WIN_A
# 417458    orthodox     139.0     140.0  ...    0.0   -0.0    win_A
# 417469    southpaw     139.0     140.0  ...    5.0    0.0      win_A
# 417775   southpaw      139.0     140.0  ...    1.0    1.0       draw
#
#         decision  judge1_A  judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 31            UD      58.0     -54.0      57.0      54.0     58.0     54.0
# 32            SD      58.0      54.0      57.0      54.0     58.0     54.0
# 33           RTD      58.0      54.0      57.0      54.0     58.0     54.0
# 34           NaN      58.0      54.0      57.0      54.0     58.0     54.0
# 35            KO      58.0      54.0      57.0      54.0     58.0     54.0
# ...          ...       ...       ...       ...       ...      ...      ...
# 417224        MD     113.0     113.0     116.0     112.0    117.0    109.0
# 417445       PTS      58.0       NaN      57.0      54.0     58.0     54.0
# 417458        KO      58.0      54.0      57.0      54.0     58.0     54.0
# 417469       NWS      58.0      54.0      57.0       NaN     58.0     54.0
# 417775       NaN      58.0      54.0      57.0      54.0     58.0     54.0
#
# [13614 rows x 26 columns]>

# %%
df[df['age_A'] < 0].count()
df[df['age_B'] < 0].count()
# Out:
# age_A       0
# age_B       0
# height_A    0
# height_B    0
# reach_A     0
# reach_B     0
# stance_A    0
# stance_B    0
# weight_A    0
# weight_B    0
# won_A       0
# won_B       0
# lost_A      0
# lost_B      0
# drawn_A     0
# drawn_B     0
# kos_A       0
# kos_B       0
# result      0
# decision    0
# judge1_A    0
# judge1_B    0
# judge2_A    0
# judge2_B    0
# judge3_A    0
# judge3_B    0
# dtype: int64

# %%
# if the age is under 18 then we will randomly generate a random age for the boxer between 

df['age_A'] = df['age_A'].apply(lambda x: rd.randint(18, 43) if x < 18 else x)
df['age_B'] = df['age_B'].apply(lambda x: rd.randint(18, 43) if x < 18 else x)

# %%
df[df['age_A'] < 18].count()
# Out:
# age_A       0
# age_B       0
# height_A    0
# height_B    0
# reach_A     0
# reach_B     0
# stance_A    0
# stance_B    0
# weight_A    0
# weight_B    0
# won_A       0
# won_B       0
# lost_A      0
# lost_B      0
# drawn_A     0
# drawn_B     0
# kos_A       0
# kos_B       0
# result      0
# decision    0
# judge1_A    0
# judge1_B    0
# judge2_A    0
# judge2_B    0
# judge3_A    0
# judge3_B    0
# dtype: int64

# %%
df[df['age_B'] < 18].count()
# Out:
# age_A       0
# age_B       0
# height_A    0
# height_B    0
# reach_A     0
# reach_B     0
# stance_A    0
# stance_B    0
# weight_A    0
# weight_B    0
# won_A       0
# won_B       0
# lost_A      0
# lost_B      0
# drawn_A     0
# drawn_B     0
# kos_A       0
# kos_B       0
# result      0
# decision    0
# judge1_A    0
# judge1_B    0
# judge2_A    0
# judge2_B    0
# judge3_A    0
# judge3_B    0
# dtype: int64

# %%
df[df['age_B'] == 15].count()
# Out:
# age_A       0
# age_B       0
# height_A    0
# height_B    0
# reach_A     0
# reach_B     0
# stance_A    0
# stance_B    0
# weight_A    0
# weight_B    0
# won_A       0
# won_B       0
# lost_A      0
# lost_B      0
# drawn_A     0
# drawn_B     0
# kos_A       0
# kos_B       0
# result      0
# decision    0
# judge1_A    0
# judge1_B    0
# judge2_A    0
# judge2_B    0
# judge3_A    0
# judge3_B    0
# dtype: int64

# %% [markdown]
# ## Height

# %%
df['height_A'] = df['height_A'].abs()
df['height_B'] = df['height_B'].abs()


def estimate_height(weight):
    if weight < 62: return np.random.normal(168, 5)   # Featherweight
    elif weight < 70: return np.random.normal(173, 6) # Lightweight
    elif weight < 80: return np.random.normal(178, 6) # Middleweight
    elif weight < 90: return np.random.normal(183, 7) # Light Heavy
    else: return np.random.normal(188, 7)             # Heavyweight

df['height_A'] = df.apply(lambda row: estimate_height(row['weight_A']) if pd.isna(row['height_A']) else row['height_A'], axis=1)
df['height_B'] = df.apply(lambda row: estimate_height(row['weight_B']) if pd.isna(row['height_B']) else row['height_B'], axis=1)

# %% [markdown]
# ## Height A

# %%
df['height_A'].min()
# issue with minimal height
# Out:
# 2.0

# %%
df['height_A'].max()
# Out:
# 255.0

# %%
df['height_A'].mean()
# Out:
# 173.61339713105423

# %% [markdown]
# ## Height B

# %%
df['height_B'].min()
# Out:
# 15.0

# %%
df['height_B'].max()
# Out:
# 255.0

# %%
df['height_B'].mean()
# Out:
# 173.69597987706467

# %% [markdown]
# # Cleaning up Height Data to be valid

# %%
# Step 1: Remove negative values by using abs()
df['height_A'] = df['height_A'].abs()
df['height_B'] = df['height_B'].abs()

# Step 2: Set unrealistic heights to NaN (outside boxing range)
df['height_A'] = df['height_A'].apply(lambda x: np.nan if x < 150 or x > 210 else x)
df['height_B'] = df['height_B'].apply(lambda x: np.nan if x < 150 or x > 210 else x)

# Step 3: Refill missing heights based on weight class (your method)
df['height_A'] = df.apply(lambda row: estimate_height(row['weight_A']) if pd.isna(row['height_A']) else row['height_A'], axis=1)
df['height_B'] = df.apply(lambda row: estimate_height(row['weight_B']) if pd.isna(row['height_B']) else row['height_B'], axis=1)


df['height_A'] = df['height_A'].fillna(df['height_A'].mean())
df['height_B'] = df['height_B'].fillna(df['height_B'].mean())

# %%
df['height_A'].min()
# Out:
# 150.0

# %%
df['height_A'].max()
# Out:
# 209.903275239644

# %%
df['height_B'].min()
# Out:
# 150.0

# %%
df['height_B'].max()
# Out:
# 210.0

# %% [markdown]
# # Clean up on Reach Data

# %%
def reach_estimation(height):
    if height < 165:
        return np.random.normal(height + 3, 3)
    elif height < 175:
        return np.random.normal(height + 7, 3)
    elif height < 185:
        return np.random.normal(height + 9, 4)
    else:
        return np.random.normal(height + 11, 4)

# %%
df['reach_A'] = df.apply(
    lambda row: reach_estimation(row['height_A']) if pd.isna(row['reach_A']) else row['reach_A'],
    axis=1
)

df['reach_B'] = df.apply(
    lambda row: reach_estimation(row['height_B']) if pd.isna(row['reach_B']) else row['reach_B'],
    axis=1
)

# %%
df['reach_A'] = df['reach_A'].apply(lambda x: np.nan if x < 150 or x > 220 else x)
df['reach_B'] = df['reach_B'].apply(lambda x: np.nan if x < 150 or x > 220 else x)

# %%
df['reach_A'] = df['reach_A'].fillna(
    df['height_A'].apply(lambda r: reach_estimation(r))
)

df['reach_B'] = df['reach_B'].fillna(
    df['height_B'].apply(lambda r: reach_estimation(r))
)

# %%
df['reach_A'].min()
# Out:
# 144.70998572125174

# %%
df['reach_A'].max()
# Out:
# 223.66881196870267

# %%
df['reach_A'].mean()
# Out:
# 178.42653914349248

# %% [markdown]
# Reach B

# %%
df['reach_B'].min()
# Out:
# 147.0756527835412

# %%
df['reach_B'].min()
# Out:
# 147.0756527835412

# %%
df['reach_B'].max()
# Out:
# 222.2242747917034

# %%
df['reach_B'].mean()
# Out:
# 178.28572015231717

# %%
df['reach_A'].isna().sum()
# Out:
# 0

# %% [markdown]
# # Stance cleaning

# %%
# Standardise the stance

df['stance_A'].unique()
# Out:
# array(['orthodox', 'southpaw', nan, 'ORTHODOX', '  orthodox  ',
#        'SOUTHPAW', ' southpaw ', '  southpaw  ', ' orthodox ', '  nan  ',
#        ' SOUTHPAW ', '  SOUTHPAW  ', 'NAN', '  ORTHODOX  ', ' ORTHODOX ',
#        ' nan ', '   southpaw   ', '   orthodox   ', '  NAN  ',
#        '   nan   ', '   ORTHODOX   ', '   NAN   ', ' NAN ',
#        '   SOUTHPAW   '], dtype=object)

# %%
df['stance_B'].unique()
# Out:
# array(['orthodox', 'southpaw', ' orthodox ', '  orthodox  ', 'ORTHODOX',
#        nan, 'SOUTHPAW', '  SOUTHPAW  ', ' southpaw ', '  southpaw  ',
#        'NAN', '  nan  ', ' nan ', '   orthodox   ', '  ORTHODOX  ',
#        ' ORTHODOX ', '   southpaw   ', '  NAN  ', ' NAN ',
#        '   ORTHODOX   ', ' SOUTHPAW ', '   nan   ', '   NAN   '],
#       dtype=object)

# %% [markdown]
# So in the dataset there are predominantly two stances, orthodox or southpaw. So we will randomly generate a stance for the boxer

# %%
def clean_stance_columns(column):
    return (
        column
        .str.strip()
        .str.lower() 
        .replace(['nan', 'none', '', 'null'], np.nan)
        .replace({
            'orthodox': 'Orthodox',
            'southpaw': 'Southpaw',
            'orthdox': 'Orthodox',     # Handling any possible misspellings
            ' southpaw ': 'Southpaw',
            ' orthodox ': 'Orthodox',
        })
    )

df['stance_A'] = clean_stance_columns(df['stance_A'])
df['stance_B'] = clean_stance_columns(df['stance_B'])

# %%
df['stance_B'].unique()
# Out:
# array(['Orthodox', 'Southpaw', nan], dtype=object)

# %%
df['stance_A'].unique()
# Out:
# array(['Orthodox', 'Southpaw', nan], dtype=object)

# %%
stances = ['Orthodox', 'Southpaw', 'Switch-up', 'Peek-a-boo']
# I included other stances to fillna

df['stance_A'] = df['stance_A'].fillna(np.random.choice(stances, p=[0.55, 0.25, 0.15, 0.05]))
df['stance_B'] = df['stance_B'].fillna(np.random.choice(stances, p=[0.55, 0.25, 0.15, 0.05]))

# %%
df['stance_A'].isna().sum()
# Out:
# 0

# %%
df['stance_B'].isna().sum()
# Out:
# 0

# %%
df['stance_A'].unique()
# Out:
# array(['Orthodox', 'Southpaw'], dtype=object)

# %%
df['stance_B'].unique()
# Out:
# array(['Orthodox', 'Southpaw'], dtype=object)

# %%
df.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %% [markdown]
# # Weight of the boxer

# %%
df['weight_A'].isna().sum()
# Out:
# 20215

# %%
df['weight_B'].isna().sum()
# Out:
# 20179

# %%
df['weight_A'] = df['weight_A'].apply(lambda x: np.nan if x < 40 or x > 130 else x)
df['weight_B'] = df['weight_B'].apply(lambda x: np.nan if x < 40 or x > 130 else x)

# %%
def estimate_weight(height):
    if height < 165: return np.random.normal(60, 5)
    elif height < 170: return np.random.normal(65, 6)
    elif height < 175: return np.random.normal(72, 7)
    elif height < 180: return np.random.normal(78, 8)
    elif height < 185: return np.random.normal(85, 9)  
    else: return np.random.normal(95, 10)

# %%
df['weight_A'] = df.apply(lambda row: estimate_weight(row['height_A']) if pd.isna(row['weight_A']) else row['weight_A'], axis=1)
df['weight_B'] = df.apply(lambda row: estimate_weight(row['height_B']) if pd.isna(row['weight_B']) else row['weight_B'], axis=1)

# %%
df['weight_A'].isna().sum()
# Out:
# 0

# %%
df['weight_B'].isna().sum()
# Out:
# 0

# %% [markdown]
# Interestingly we could have filled these weight values in with a regression model however this has been ruled out of the scope of the project for future works due to the priority backlog.

# %%
df.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %%
df['won_A'].head(10)
# Out:
# 0    37.0
# 1    48.0
# 2    23.0
# 3    46.0
# 4    45.0
# 5     NaN
# 6    43.0
# 7    42.0
# 8    44.0
# 9    26.0
# Name: won_A, dtype: float64

# %% [markdown]
# ## Won Data Standardisation
# This data presents how many victories the fighters possess on their record.

# %%
df['won_A'].isna().sum()
# Out:
# 20205

# %%
df['won_B'].isna().sum()
# Out:
# 20185

# %%
df['won_A'] = df['won_A'].abs()
df['won_B'] = df['won_B'].abs()

# %%
df['won_A'] = df['won_A'].round().astype('Int64')
df['won_B'] = df['won_B'].round().astype('Int64')

# %%
mean_wins = round(df['won_A'].mean())
df['won_A'] = df['won_A'].fillna(mean_wins).astype('Int64')

# %%
mean_wins = round(df['won_B'].mean())
df['won_B'] = df['won_B'].fillna(mean_wins).astype('Int64')

# %%
df['won_A'].isna().sum()
# Out:
# 0

# %%
df['won_B'].isna().sum()
# Out:
# 0

# %%
# find the won minimum and maximum
df['won_B'].min()
# Out:
# 0

# %%
df['won_B'].max()
# Out:
# 251

# %%
df['won_B'].mean().round()
# Out:
# 15.0

# %%
df['won_A'].max()
# Out:
# 332

# %%
df['won_A'].mean().round()
# Out:
# 23.0

# %%
# some data shows highly inaccurate figures such as
(df['won_A'] > 70).sum()


# For this I will get random integer to replace these figures with an integer between 1 and 50
# Out:
# 23819

# %%
df.loc[df['won_A'] > 70, 'won_A'] = np.random.randint(1, 51, size=df[df['won_A'] > 70].shape[0])

# %%
df['won_A'].max()
# Out:
# 70

# %%
df['won_A'].max()
# Out:
# 70

# %%
df.loc[df['won_B'] > 70, 'won_B'] = np.random.randint(1, 51, size=df[df['won_B'] > 70].shape[0])

# %%
df['won_B'].min()
# Out:
# 0

# %%
df['won_B'].max()
# Out:
# 70

# %%
df.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %% [markdown]
# ## Lost Data Standardisation
# This data presents how many losses the fighters possess on their record.

# %%
df['lost_A'] = df['lost_A'].abs()
df['lost_B'] = df['lost_B'].abs()

# %%
df['lost_A'] = df['lost_A'].round().astype('Int64')
df['lost_B'] = df['lost_B'].round().astype('Int64')

# %%
df['lost_A'].min()
# Out:
# 0

# %%
df['lost_A'].max()
# Out:
# 198

# %%
df['lost_B'].min()
# Out:
# 0

# %%
df['lost_B'].max()
# Out:
# 511

# %%
df.loc[df['lost_A'] > 130, 'lost_A'] = np.random.randint(1, 120, size=df[df['lost_A'] > 130].shape[0])
df.loc[df['lost_B'] > 130, 'lost_B'] = np.random.randint(1, 120, size=df[df['lost_B'] > 130].shape[0])

# %%
df['lost_A'].max()
# Out:
# 130

# %%
df['lost_B'].max()
# Out:
# 130

# %%
df.columns
# Out:
# Index(['age_A', 'age_B', 'height_A', 'height_B', 'reach_A', 'reach_B',
#        'stance_A', 'stance_B', 'weight_A', 'weight_B', 'won_A', 'won_B',
#        'lost_A', 'lost_B', 'drawn_A', 'drawn_B', 'kos_A', 'kos_B', 'result',
#        'decision', 'judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A',
#        'judge3_B'],
#       dtype='object')

# %%
df['drawn_A'] = df['drawn_A'].apply(lambda x: np.nan if x < 0 or x > 20 else x)
df['drawn_B'] = df['drawn_B'].apply(lambda x: np.nan if x < 0 or x > 20 else x)

# %%
df['drawn_A'] = df['drawn_A'].fillna(df['drawn_A'].median())
df['drawn_B'] = df['drawn_B'].fillna(df['drawn_B'].median())

# %%
df['drawn_A'] = df['drawn_A'].astype('Int64')
df['drawn_B'] = df['drawn_B'].astype('Int64')

# %%
df['drawn_A'].max()
# Out:
# 20

# %% [markdown]
# # KO's Standardisation of the Data
# This reports the number of knockouts the individual has had in their career.

# %%
# turn it into a positive number
df['lost_A'] = df['lost_A'].abs()
df['lost_B'] = df['lost_B'].abs()

# %%
df['kos_A'] = df['kos_A'].apply(lambda x: x if pd.notna(x) and 0 <= x <= 70 else np.nan)
df['kos_B'] = df['kos_B'].apply(lambda x: x if pd.notna(x) and 0 <= x <= 70 else np.nan)

# %%
df['kos_A'] = df.apply(lambda row: min(row['kos_A'], row['won_A']) if pd.notna(row['kos_A']) else np.nan, axis=1)
df['kos_B'] = df.apply(lambda row: min(row['kos_B'], row['won_B']) if pd.notna(row['kos_B']) else np.nan, axis=1)

# %%
df['kos_A'] = df['kos_A'].astype('float')
df['won_A'] = df['won_A'].astype('float')
df['kos_B'] = df['kos_B'].astype('float')
df['won_B'] = df['won_B'].astype('float')

# %%
avg_ko_ratio = (df['kos_A'] / df['won_A']).mean()

df['kos_A'] = df.apply(
    lambda row: round(row['won_A'] * avg_ko_ratio)
    if pd.isna(row['kos_A']) and pd.notna(row['won_A']) and row['won_A'] > 0
    else row['kos_A'],
    axis=1
)

df['kos_B'] = df.apply(
    lambda row: round(row['won_B'] * avg_ko_ratio)
    if pd.isna(row['kos_B']) and pd.notna(row['won_B']) and row['won_B'] > 0
    else row['kos_B'],
    axis=1
)

# %%
df['kos_A'] = df['kos_A'].round().astype('Int64')
df['kos_B'] = df['kos_B'].round().astype('Int64')

# %%
(df['kos_A'] > df['won_A']).sum()
# Out:
# 0

# %%
df[['won_A', 'kos_A']].head()
# Out:
#    won_A  kos_A
# 0   37.0     33
# 1   48.0     34
# 2   23.0     13
# 3   46.0     32
# 4   45.0     32

# %%
df['kos_B'].isna().sum()
# Out:
# 3271

# %%
df['kos_A'].isna().sum()
# Out:
# 1102

# %% [markdown]
# # Judge Score Card Standardisation

# %%
judge_columns = ['judge1_A', 'judge1_B', 'judge2_A', 'judge2_B', 'judge3_A', 'judge3_B']
df[judge_columns].isna().sum()
# Out:
# judge1_A    20198
# judge1_B    20211
# judge2_A    20215
# judge2_B    20190
# judge3_A    20169
# judge3_B    20191
# dtype: int64

# %%
for col in judge_columns:
    df[col] = df[col].apply(lambda x: np.nan if x < 0 or x > 120 else x)

df['judge1_A'] = df['judge1_A'].fillna(df[['judge1_A', 'judge2_A', 'judge3_A']].mean(axis=1))
df['judge1_B'] = df['judge1_B'].fillna(df[['judge1_B', 'judge2_B', 'judge3_B']].mean(axis=1))

# %%
judge_columns_A = ['judge1_A', 'judge2_A', 'judge3_A']
judge_columns_B = ['judge1_B', 'judge2_B', 'judge3_B']

# Step 1: Remove invalid values (<0 or >120)
for col in judge_columns_A + judge_columns_B:
    df[col] = df[col].apply(lambda x: np.nan if x < 0 or x > 120 else x)

# Step 2: Fill missing values row-wise using A-side averages
df[judge_columns_A] = df[judge_columns_A].apply(
    lambda row: row.fillna(row.mean()), axis=1
)

# Step 3: Fill missing values row-wise using B-side averages
df[judge_columns_B] = df[judge_columns_B].apply(
    lambda row: row.fillna(row.mean()), axis=1
)

# %%
df.isna().sum()
# Out:
# age_A           0
# age_B           0
# height_A        0
# height_B        0
# reach_A         0
# reach_B         0
# stance_A        0
# stance_B        0
# weight_A        0
# weight_B        0
# won_A           0
# won_B           0
# lost_A      20161
# lost_B      20208
# drawn_A         0
# drawn_B         0
# kos_A        1102
# kos_B        3271
# result      19361
# decision    19352
# judge1_A      299
# judge1_B      285
# judge2_A      299
# judge2_B      285
# judge3_A      299
# judge3_B      285
# dtype: int64

# %% [markdown]
# # Result Standardisation of Data
# From the given bout who won the fight.

# %%
def infer_result(row):
    if row['kos_A'] > 0: return 'win_A'
    if row['kos_B'] > 0: return 'win_B'

    a_score = (row['judge1_A'] + row['judge2_A'] + row['judge3_A']).fillna(0)
    b_score = (row['judge1_B'] + row['judge2_B'] + row['judge3_B']).fillna(0)

    if a_score.sum() > b_score.sum(): return 'win_A'
    if a_score.sum() < b_score.sum(): return 'win_B'
    return 'draw'

# %%
df['result'].isna().sum()
# Out:
# 19361

# %%
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  Orthodox  Orthodox
# 1   26.0   31.0     173.0     185.0    179.0    185.0  Orthodox  Orthodox
# 2   28.0   43.0     176.0     175.0    178.0    179.0  Orthodox  Orthodox
# 3   25.0   29.0     175.0     174.0    178.0    180.0  Orthodox  Orthodox
# 4   25.0   35.0     175.0     173.0    179.0    170.0  Orthodox  Orthodox
#
#     weight_A    weight_B  ...  kos_A  kos_B  result  decision  judge1_A  \
# 0  74.221126   85.067857  ...     33     34    draw       NaN     110.0
# 1  75.775768  101.736004  ...     34     32   win_A        UD     120.0
# 2  73.556933   73.959501  ...     13     33   win_B        KO      58.0
# 3  70.045370   78.972242  ...     32     16   win_A        KO      47.0
# 4  69.239917   75.011529  ...     32     33   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0     118.0     115.0     113.0    114.0    114.0
# 1     108.0     120.0     108.0    120.0    108.0
# 2      54.0      57.0      54.0     58.0     54.0
# 3      48.0      49.0      46.0     48.0     47.0
# 4     110.0     119.0     109.0    117.0    111.0
#
# [5 rows x 26 columns]

# %%
df['decision'] = df['decision'].str.strip().str.upper().replace({
    'TECHNICAL KNOCKOUT': 'TKO',
    'KNOCKOUT': 'KO',
    'UNANIMOUS': 'UD',
    'SPLIT': 'SD',
    'MAJORITY': 'MD',
    'POINTS': 'UD',
    'DRAW ': 'DRAW',
    ' DQ': 'DQ'
})

# %%
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  Orthodox  Orthodox
# 1   26.0   31.0     173.0     185.0    179.0    185.0  Orthodox  Orthodox
# 2   28.0   43.0     176.0     175.0    178.0    179.0  Orthodox  Orthodox
# 3   25.0   29.0     175.0     174.0    178.0    180.0  Orthodox  Orthodox
# 4   25.0   35.0     175.0     173.0    179.0    170.0  Orthodox  Orthodox
#
#     weight_A    weight_B  ...  kos_A  kos_B  result  decision  judge1_A  \
# 0  74.221126   85.067857  ...     33     34    draw       NaN     110.0
# 1  75.775768  101.736004  ...     34     32   win_A        UD     120.0
# 2  73.556933   73.959501  ...     13     33   win_B        KO      58.0
# 3  70.045370   78.972242  ...     32     16   win_A        KO      47.0
# 4  69.239917   75.011529  ...     32     33   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0     118.0     115.0     113.0    114.0    114.0
# 1     108.0     120.0     108.0    120.0    108.0
# 2      54.0      57.0      54.0     58.0     54.0
# 3      48.0      49.0      46.0     48.0     47.0
# 4     110.0     119.0     109.0    117.0    111.0
#
# [5 rows x 26 columns]

# %%
df['decision'].isna().sum()
# Out:
# 19352

# %%
def fill_decision(row):
    # Keep existing decision
    if pd.notna(row['decision']):
        return row['decision']

    # Infer based on KO counts
    if pd.notna(row['kos_A']) and row['kos_A'] > 0:
        return 'KO'
    if pd.notna(row['kos_B']) and row['kos_B'] > 0:
        return 'KO'

    # If result exists, apply logic safely
    if pd.notna(row['result']):
        if row['result'] in ['win_A', 'win_B']:
            return 'UD'  # points win
        if row['result'] == 'draw':
            return 'DRAW'

    return 'UNKNOWN'  # Fallback

df['decision'] = df.apply(fill_decision, axis=1)

# %%
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  Orthodox  Orthodox
# 1   26.0   31.0     173.0     185.0    179.0    185.0  Orthodox  Orthodox
# 2   28.0   43.0     176.0     175.0    178.0    179.0  Orthodox  Orthodox
# 3   25.0   29.0     175.0     174.0    178.0    180.0  Orthodox  Orthodox
# 4   25.0   35.0     175.0     173.0    179.0    170.0  Orthodox  Orthodox
#
#     weight_A    weight_B  ...  kos_A  kos_B  result  decision  judge1_A  \
# 0  74.221126   85.067857  ...     33     34    draw        KO     110.0
# 1  75.775768  101.736004  ...     34     32   win_A        UD     120.0
# 2  73.556933   73.959501  ...     13     33   win_B        KO      58.0
# 3  70.045370   78.972242  ...     32     16   win_A        KO      47.0
# 4  69.239917   75.011529  ...     32     33   win_A        UD     118.0
#
#    judge1_B  judge2_A  judge2_B judge3_A judge3_B
# 0     118.0     115.0     113.0    114.0    114.0
# 1     108.0     120.0     108.0    120.0    108.0
# 2      54.0      57.0      54.0     58.0     54.0
# 3      48.0      49.0      46.0     48.0     47.0
# 4     110.0     119.0     109.0    117.0    111.0
#
# [5 rows x 26 columns]

# %% [markdown]
# # Add Weight class
# This is to categorise both fighters by their weight class

# %%
def assign_weight_class(weight):
    if weight <= 50.8: return "Flyweight"
    elif weight <= 53.5: return "Bantamweight"
    elif weight <= 57.2: return "Featherweight"
    elif weight <= 61.2: return "Lightweight"
    elif weight <= 63.5: return "Super Lightweight"
    elif weight <= 66.7: return "Welterweight"
    elif weight <= 69.9: return "Super Welterweight"
    elif weight <= 72.6: return "Middleweight"
    elif weight <= 76.2: return "Super Middleweight"
    elif weight <= 79.4: return "Light Heavyweight"
    elif weight <= 90.7: return "Cruiserweight"
    else: return "Heavyweight"

# %%
df['class_A'] = df['weight_A'].apply(assign_weight_class)
df['class_B'] = df['weight_B'].apply(assign_weight_class)

# %%
df['class_A'] = df['weight_A'].apply(assign_weight_class)
df['class_B'] = df['weight_B'].apply(assign_weight_class)

# %%
df['class_A'].value_counts()
# Out:
# class_A
# Heavyweight           79081
# Cruiserweight         66925
# Super Middleweight    48024
# Super Welterweight    41458
# Middleweight          37641
# Light Heavyweight     35710
# Welterweight          34992
# Lightweight           23804
# Super Lightweight     20054
# Featherweight         10528
# Bantamweight           3209
# Flyweight              1596
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  stance_B  \
# 0   35.0   27.0     179.0     175.0    178.0    179.0  Orthodox  Orthodox
# 1   26.0   31.0     173.0     185.0    179.0    185.0  Orthodox  Orthodox
# 2   28.0   43.0     176.0     175.0    178.0    179.0  Orthodox  Orthodox
# 3   25.0   29.0     175.0     174.0    178.0    180.0  Orthodox  Orthodox
# 4   25.0   35.0     175.0     173.0    179.0    170.0  Orthodox  Orthodox
#
#     weight_A    weight_B  ...  result  decision  judge1_A  judge1_B  judge2_A  \
# 0  74.221126   85.067857  ...    draw        KO     110.0     118.0     115.0
# 1  75.775768  101.736004  ...   win_A        UD     120.0     108.0     120.0
# 2  73.556933   73.959501  ...   win_B        KO      58.0      54.0      57.0
# 3  70.045370   78.972242  ...   win_A        KO      47.0      48.0      49.0
# 4  69.239917   75.011529  ...   win_A        UD     118.0     110.0     119.0
#
#    judge2_B  judge3_A  judge3_B             class_A             class_B
# 0     113.0     114.0     114.0  Super Middleweight       Cruiserweight
# 1     108.0     120.0     108.0  Super Middleweight         Heavyweight
# 2      54.0      58.0      54.0  Super Middleweight  Super Middleweight
# 3      46.0      48.0      47.0        Middleweight   Light Heavyweight
# 4     109.0     117.0     111.0  Super Welterweight  Super Middleweight
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#         age_A  age_B  height_A  height_B  reach_A  reach_B  stance_A  \
# 418072   24.0   27.0     184.0     185.0    178.0    196.0  Orthodox
# 418076   26.0   26.0     173.0     173.0    178.0    178.0  Orthodox
# 418084   26.0   34.0     171.0     170.0    169.0    178.0  Orthodox
# 418085   22.0   20.0     173.0     173.0    178.0    178.0  Southpaw
# 418090   33.0   19.0     173.0     173.0    178.0    178.0  Southpaw
#
#         stance_B   weight_A    weight_B  ...     result  decision  judge1_A  \
# 418072  Orthodox  77.893897  113.597016  ...      win_a       PTS      58.0
# 418076  Orthodox  57.847888   75.957415  ...      win_A       TKO      58.0
# 418084  Orthodox  71.253439   73.191355  ...    win_A          KO      10.0
# 418085  Southpaw  81.222000   68.636832  ...       draw       PTS      58.0
# 418090  Southpaw  72.847070   66.539530  ...       draw       PTS      58.0
#
#         judge1_B  judge2_A  judge2_B  judge3_A  judge3_B             class_A  \
# 418072      54.0      57.0      54.0      58.0      54.0   Light Heavyweight
# 418076      54.0      57.0      54.0      58.0      54.0         Lightweight
# 418084       9.0      10.0       9.0      10.0       9.0        Middleweight
# 418085      54.0      57.0      54.0      58.0      54.0       Cruiserweight
# 418090      54.0      57.0      54.0      58.0      54.0  Super Middleweight
#
#                    class_B
# 418072         Heavyweight
# 418076  Super Middleweight
# 418084  Super Middleweight
# 418085  Super Welterweight
# 418090        Welterweight
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Data accuracy
# The boxers classification currently shows different weights fighting against one another but this is not sanctioned in boxing therefore this will be readjusted.

# %%
weight_classes = {
    "Minimumweight": 1, "Light Flyweight": 2, "Flyweight": 3, "Super Flyweight": 4,
    "Bantamweight": 5, "Super Bantamweight": 6, "Featherweight": 7, "Super Featherweight": 8,
    "Lightweight": 9, "Super Lightweight": 10, "Welterweight": 11,
    "Super Welterweight": 12, "Middleweight": 13, "Super Middleweight": 14,
    "Light Heavyweight": 15, "Cruiserweight": 16, "Heavyweight": 17
}


# Giving ranks directly (vectorized)
df['rank_A'] = df['class_A'].map(weight_classes)
df['rank_B'] = df['class_B'].map(weight_classes)

df['class_diff'] = abs(df['rank_A'] - df['rank_B'])

# Finding invalid fights (>1 class apart)
invalid = df['class_diff'] > 1
print(f"Invalid fights before fix: {invalid.sum()}")

# Randomly decide which side to adjust (vectorized)
adjust_A = np.random.rand(len(df)) > 0.5  # True = adjust A, False = adjust B

# 4️⃣ For A-adjust cases → copy class_B & weight_B
df.loc[invalid & adjust_A, 'class_A'] = df.loc[invalid & adjust_A, 'class_B']
df.loc[invalid & adjust_A, 'weight_A'] = df.loc[invalid & adjust_A, 'weight_B']

# 5️⃣ For B-adjust cases → copy class_A & weight_A
df.loc[invalid & ~adjust_A, 'class_B'] = df.loc[invalid & ~adjust_A, 'class_A']
df.loc[invalid & ~adjust_A, 'weight_B'] = df.loc[invalid & ~adjust_A, 'weight_A']

# 6️⃣ Recalculate ranks after corrections
df['rank_A'] = df['class_A'].map(weight_classes)
df['rank_B'] = df['class_B'].map(weight_classes)
df['class_diff'] = abs(df['rank_A'] - df['rank_B'])

# print(f"Invalid fights after fix: {(df['class_diff']>1).sum()}")
# Out:
# Invalid fights before fix: 251973

# %%
df.head(25)
# Out:
#     age_A  age_B  height_A  height_B     reach_A  reach_B  stance_A  stance_B  \
# 0    35.0   27.0     179.0     175.0  178.000000    179.0  Orthodox  Orthodox
# 1    26.0   31.0     173.0     185.0  179.000000    185.0  Orthodox  Orthodox
# 2    28.0   43.0     176.0     175.0  178.000000    179.0  Orthodox  Orthodox
# 3    25.0   29.0     175.0     174.0  178.000000    180.0  Orthodox  Orthodox
# 4    25.0   35.0     175.0     173.0  179.000000    170.0  Orthodox  Orthodox
# 5    24.0   31.0     175.0     175.0  179.000000    178.0  Orthodox  Orthodox
# 6    23.0   31.0     175.0     175.0  179.000000    188.0  Orthodox  Orthodox
# 7    23.0   31.0     175.0     177.0  179.000000    175.0  Orthodox  Orthodox
# 8    24.0   23.0     173.0     175.0  183.000000    179.0  Orthodox  Orthodox
# 9    27.0   26.0     177.0     175.0  183.000000    179.0  Southpaw  Southpaw
# 10   33.0   28.0     175.0     177.0  179.000000    175.0  Orthodox  Orthodox
# 11   21.0   40.0     175.0     174.0  178.000000    180.0  Orthodox  Orthodox
# 12   21.0   32.0     175.0     173.0  179.000000    188.0  Orthodox  Orthodox
# 13   21.0   30.0     175.0     175.0  179.000000    175.0  Orthodox  Orthodox
# 14   20.0   34.0     175.0     174.0  179.000000    178.0  Orthodox  Orthodox
# 15   20.0   29.0     175.0     174.0  179.000000    178.0  Orthodox  Orthodox
# 16   20.0   39.0     175.0     173.0  179.000000    173.0  Orthodox  Orthodox
# 17   24.0   39.0     175.0     170.0  179.000000    173.0  Orthodox  Orthodox
# 18   19.0   26.0     175.0     178.0  179.000000    178.0  Orthodox  Orthodox
# 19   38.0   32.0     175.0     167.0  178.000000    173.0  Orthodox  Orthodox
# 20   19.0   31.0     175.0     173.0  179.000000    178.0  Orthodox  Orthodox
# 21   19.0   34.0     175.0     168.0  179.000000    178.0  Orthodox  Orthodox
# 22   19.0   28.0     175.0     172.0  179.000000    178.0  Orthodox  Orthodox
# 23   19.0   26.0     175.0     176.0  179.000000    178.0  Orthodox  Orthodox
# 24   18.0   26.0     175.0     173.0  181.182068    178.0  Orthodox  Orthodox
#
#       weight_A    weight_B  ...  judge1_B  judge2_A  judge2_B  judge3_A  \
# 0    85.067857   85.067857  ...     118.0     115.0     113.0     114.0
# 1   101.736004  101.736004  ...     108.0     120.0     108.0     120.0
# 2    73.556933   73.959501  ...      54.0      57.0      54.0      58.0
# 3    70.045370   70.045370  ...      48.0      49.0      46.0      48.0
# 4    69.239917   69.239917  ...     110.0     119.0     109.0     117.0
# 5    66.821831   66.821831  ...      54.0      57.0      54.0      58.0
# 6    87.167596   77.531389  ...     113.0     117.0     111.0     113.0
# 7    57.287535   57.287535  ...      82.0      88.0      54.0      89.0
# 8    73.344207   73.344207  ...      54.0     114.0     114.0     117.0
# 9    69.216352   69.216352  ...     115.0     109.0     118.0     111.0
# 10   78.988220   73.621671  ...      54.0      57.0      54.0      58.0
# 11   75.427287   72.245114  ...     109.0     119.0     109.0     118.0
# 12   74.256104   74.256104  ...      35.0      40.0      35.0      40.0
# 13   82.216023   91.227748  ...      44.0      49.0      45.0      53.5
# 14   77.354795   87.352921  ...      54.0      57.0      54.0      58.0
# 15   76.129152   70.299057  ...     108.0     119.0     108.0     119.0
# 16   64.686729   64.579861  ...     108.5     120.0     108.0     119.0
# 17   62.516601   62.516601  ...      54.0      57.0      54.0      57.5
# 18   80.133680   80.133680  ...      54.0      57.0      54.0      58.0
# 19   61.274994   61.274994  ...      73.0      78.0      73.0      78.0
# 20   83.029139   83.029139  ...      54.0      57.0      54.0      58.0
# 21   70.654251   70.654251  ...      54.0      57.0      54.0      58.0
# 22   84.939124   85.504335  ...      54.0      57.0      54.0      58.0
# 23   71.920839   71.920839  ...      54.0      57.0      54.0      58.0
# 24   80.198711   80.125984  ...      72.0      80.0      72.0      80.0
#
#     judge3_B             class_A             class_B  rank_A rank_B class_diff
# 0      114.0       Cruiserweight       Cruiserweight      16     16          0
# 1      108.0         Heavyweight         Heavyweight      17     17          0
# 2       54.0  Super Middleweight  Super Middleweight      14     14          0
# 3       47.0        Middleweight        Middleweight      13     13          0
# 4      111.0  Super Welterweight  Super Welterweight      12     12          0
# 5       54.0  Super Welterweight  Super Welterweight      12     12          0
# 6      112.0       Cruiserweight   Light Heavyweight      16     15          1
# 7       82.0         Lightweight         Lightweight       9      9          0
# 8      111.0  Super Middleweight  Super Middleweight      14     14          0
# 9      116.0  Super Welterweight  Super Welterweight      12     12          0
# 10      54.0   Light Heavyweight  Super Middleweight      15     14          1
# 11     110.0  Super Middleweight        Middleweight      14     13          1
# 12      35.0  Super Middleweight  Super Middleweight      14     14          0
# 13      45.0       Cruiserweight         Heavyweight      16     17          1
# 14      54.0   Light Heavyweight       Cruiserweight      15     16          1
# 15     108.0  Super Middleweight        Middleweight      14     13          1
# 16     109.0        Welterweight        Welterweight      11     11          0
# 17      54.0   Super Lightweight   Super Lightweight      10     10          0
# 18      54.0       Cruiserweight       Cruiserweight      16     16          0
# 19      73.0   Super Lightweight   Super Lightweight      10     10          0
# 20      54.0       Cruiserweight       Cruiserweight      16     16          0
# 21      54.0        Middleweight        Middleweight      13     13          0
# 22      54.0       Cruiserweight       Cruiserweight      16     16          0
# 23      54.0        Middleweight        Middleweight      13     13          0
# 24      72.0       Cruiserweight       Cruiserweight      16     16          0
#
# [25 rows x 31 columns]

# %%
df.tail(25)
# Out:
#         age_A  age_B   height_A    height_B     reach_A     reach_B  stance_A  \
# 417974   22.0   26.0  192.66413  185.000000  201.000000  178.000000  Orthodox
# 417975   24.0   23.0  173.00000  159.000000  180.428095  157.194812  Orthodox
# 417977   38.0   30.0  180.00000  173.000000  185.000000  173.000000  Orthodox
# 417982   34.0   30.0  178.00000  173.000000  178.000000  178.000000  Orthodox
# 417983   26.0   27.0  175.00000  178.000000  180.000000  178.000000  Orthodox
# 417995   25.0   32.0  173.00000  173.000000  178.000000  178.000000  Southpaw
# 417998   29.0   24.0  169.00000  173.000000  178.000000  178.000000  Orthodox
# 418003   22.0   25.0  173.00000  173.000000  178.000000  181.022529  Orthodox
# 418006   20.0   21.0  173.00000  174.000000  178.000000  179.000000  Orthodox
# 418027   28.0   26.0  188.00000  185.000000  178.000000  198.000000  Orthodox
# 418031   20.0   35.0  180.00000  178.000000  178.000000  178.000000  Orthodox
# 418035   30.0   25.0  179.00000  173.000000  178.000000  178.000000  Orthodox
# 418038   28.0   26.0  173.00000  173.000000  178.000000  178.000000  Orthodox
# 418039   31.0   26.0  168.00000  173.000000  178.000000  177.000000  Orthodox
# 418046   23.0   30.0  173.00000  173.000000  178.000000  178.000000  Orthodox
# 418055   31.0   26.0  173.00000  173.000000  178.000000  178.000000  Orthodox
# 418062   20.0   32.0  173.00000  173.000000  178.000000  178.000000  Southpaw
# 418064   27.0   40.0  191.00000  173.000000  201.000000  178.000000  Orthodox
# 418066   26.0   23.0  150.00000  165.000000  178.000000  178.000000  Orthodox
# 418068   31.0   25.0  173.00000  190.484328  174.000000  178.000000  Orthodox
# 418072   24.0   27.0  184.00000  185.000000  178.000000  196.000000  Orthodox
# 418076   26.0   26.0  173.00000  173.000000  178.000000  178.000000  Orthodox
# 418084   26.0   34.0  171.00000  170.000000  169.000000  178.000000  Orthodox
# 418085   22.0   20.0  173.00000  173.000000  178.000000  178.000000  Southpaw
# 418090   33.0   19.0  173.00000  173.000000  178.000000  178.000000  Southpaw
#
#         stance_B    weight_A    weight_B  ...  judge1_B  judge2_A  judge2_B  \
# 417974  Orthodox  111.720354   97.026016  ...      54.0      58.0      54.0
# 417975  Orthodox   55.233829   55.233829  ...      54.0      57.0      54.0
# 417977  Orthodox   67.515466   67.515466  ...      92.0      95.5      92.0
# 417982  Orthodox   68.454318   68.454318  ...      54.0      57.0      54.0
# 417983  Orthodox   76.381242   72.759228  ...      54.0      45.0      47.0
# 417995  Southpaw   75.536904   74.381827  ...      54.0      57.0      54.0
# 417998  Orthodox   75.517884   75.517884  ...      54.0      57.0      54.0
# 418003  Orthodox   56.075380   56.075380  ...      54.0      57.0      54.0
# 418006  Orthodox   57.789970   57.789970  ...      54.0      57.0      54.0
# 418027  Orthodox  110.586430   82.007454  ...      54.0      57.0      54.0
# 418031  Orthodox   73.140219   73.140219  ...      54.0      40.0      36.0
# 418035  Orthodox   56.338194   56.338194  ...      54.0      57.0      54.0
# 418038  Orthodox  125.000000  125.000000  ...      54.0      57.0      54.0
# 418039  Orthodox   67.207576   67.207576  ...      54.0      57.0      54.0
# 418046  Orthodox   76.264394   76.264394  ...      54.0      58.0      54.0
# 418055  Orthodox   71.609731   74.810116  ...      54.0      57.0      54.0
# 418062  Southpaw   71.859931   71.859931  ...      54.0      40.0      36.0
# 418064  Orthodox   66.809195   66.809195  ...      54.0      57.0      54.0
# 418066  Orthodox   63.878067   65.370939  ...      54.0      57.0      54.0
# 418068  Orthodox  116.616716  116.616716  ...      54.0      57.0      54.0
# 418072  Orthodox   77.893897   77.893897  ...      54.0      57.0      54.0
# 418076  Orthodox   75.957415   75.957415  ...      54.0      57.0      54.0
# 418084  Orthodox   71.253439   73.191355  ...       9.0      10.0       9.0
# 418085  Southpaw   81.222000   81.222000  ...      54.0      57.0      54.0
# 418090  Southpaw   72.847070   72.847070  ...      54.0      57.0      54.0
#
#         judge3_A  judge3_B             class_A             class_B  rank_A  \
# 417974      58.0      54.0         Heavyweight         Heavyweight      17
# 417975      58.0      54.0       Featherweight       Featherweight       7
# 417977      94.0      95.0  Super Welterweight  Super Welterweight      12
# 417982      58.0      54.0  Super Welterweight  Super Welterweight      12
# 417983      45.0      49.0   Light Heavyweight  Super Middleweight      15
# 417995      57.5      54.0  Super Middleweight  Super Middleweight      14
# 417998      58.0      54.0  Super Middleweight  Super Middleweight      14
# 418003      58.0      54.0       Featherweight       Featherweight       7
# 418006      58.0      54.0         Lightweight         Lightweight       9
# 418027      58.0      54.0         Heavyweight       Cruiserweight      17
# 418031      58.0      54.0  Super Middleweight  Super Middleweight      14
# 418035      58.0      54.0       Featherweight       Featherweight       7
# 418038      58.0      54.0         Heavyweight         Heavyweight      17
# 418039      58.0      54.0  Super Welterweight  Super Welterweight      12
# 418046      58.0      54.0   Light Heavyweight   Light Heavyweight      15
# 418055      58.0      54.0        Middleweight  Super Middleweight      13
# 418062      58.0      54.0        Middleweight        Middleweight      13
# 418064      58.0      54.0  Super Welterweight  Super Welterweight      12
# 418066      58.0      54.0        Welterweight        Welterweight      11
# 418068      58.0      54.0         Heavyweight         Heavyweight      17
# 418072      58.0      54.0   Light Heavyweight   Light Heavyweight      15
# 418076      58.0      54.0  Super Middleweight  Super Middleweight      14
# 418084      10.0       9.0        Middleweight  Super Middleweight      13
# 418085      58.0      54.0       Cruiserweight       Cruiserweight      16
# 418090      58.0      54.0  Super Middleweight  Super Middleweight      14
#
#        rank_B class_diff
# 417974     17          0
# 417975      7          0
# 417977     12          0
# 417982     12          0
# 417983     14          1
# 417995     14          0
# 417998     14          0
# 418003      7          0
# 418006      9          0
# 418027     16          1
# 418031     14          0
# 418035      7          0
# 418038     17          0
# 418039     12          0
# 418046     15          0
# 418055     14          1
# 418062     13          0
# 418064     12          0
# 418066     11          0
# 418068     17          0
# 418072     15          0
# 418076     14          0
# 418084     14          1
# 418085     16          0
# 418090     14          0
#
# [25 rows x 31 columns]

# %%
df.to_csv("../data/processed/cleaned_data.csv")

# %%
df['weight_A']
# Out:
# 0          85.067857
# 1         101.736004
# 2          73.556933
# 3          70.045370
# 4          69.239917
#              ...
# 418072     77.893897
# 418076     75.957415
# 418084     71.253439
# 418085     81.222000
# 418090     72.847070
# Name: weight_A, Length: 403022, dtype: float64
